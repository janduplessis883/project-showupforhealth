# %%
import pandas as pd 

from showupforhealth.params import *
from showupforhealth.interface import *
from showupforhealth.ml_functions.preprocessor import *

# Importing default Libraries
import matplotlib.pyplot as plt
import pandas as pd 
import numpy as np
import seaborn as sns
import warnings

# Hi-resolution Plots and Matplotlib inline
# %config InlineBackend.figure_format = 'retina'
# %matplotlib inline

# Set the maximum number of rows and columns to be displayed
pd.options.display.max_rows = 1000
pd.options.display.max_columns = 1000
warnings.filterwarnings('ignore')

# "magic commands" to enable autoreload of your imported packages
# %load_ext autoreload
# %autoreload 2

# %%
data = pd.read_csv(f'{OUTPUT_DATA}training_data_no_features.csv')
data.head()
# Out:
#   Appointment booked date Appointment date Appointment status  \
# 0               10-May-22        14-Jul-22           Finished
# 1               10-May-22        14-Jul-22           Finished
# 2               10-May-22        14-Jul-22           Finished
# 3               12-May-22        05-Jul-22           Finished
# 4               17-May-22        05-Jul-22           Finished
#
#   Appointment time                  Booked by                  Clinician  \
# 0    10:00 - 10:59  FLORKO, Aleksandra (Miss)  FLORKO, Aleksandra (Miss)
# 1    10:00 - 10:59  FLORKO, Aleksandra (Miss)  FLORKO, Aleksandra (Miss)
# 2    10:00 - 10:59  FLORKO, Aleksandra (Miss)  FLORKO, Aleksandra (Miss)
# 3    09:00 - 09:59  FLORKO, Aleksandra (Miss)  FLORKO, Aleksandra (Miss)
# 4    10:00 - 10:59    LE TELLIER, Jean-Pierre  FLORKO, Aleksandra (Miss)
#
#                        Rota type  Patient ID         app datetime  temp  \
# 0  Earls Court Surgery Registrar    19581842  2022-07-14 10:00:00  21.6
# ...

# %%
for i in range(18,1,-3):
    age_filter = (data['Age in years'] < i) & (data['Appointment status'] != 'Finished')
    print(f'We have {data[age_filter].shape[0]} DNAs under the age of {i}')
# Out:
# We have 2834 DNAs under the age of 18
# We have 2401 DNAs under the age of 15
# We have 1950 DNAs under the age of 12
# We have 1552 DNAs under the age of 9
# We have 998 DNAs under the age of 6
# We have 320 DNAs under the age of 3

# %%
data_eng = feature_engeneering(data)
# Out:
# - Feature Engineering......
# 📙 Booked by Clinician
# Booked by...DONE!
# 🔠 Encode Appointment status
# encode_appointment_status...DONE!
# 🚯 Hash Patient ID
# hash_patient_id...DONE!
# 🤦🏽‍♂️ Mapping Ethnicity Category
# group_ethnicity_categories...DONE!
# 🕣 Convert Datetime Columns
# group_ethnicity_categories...DONE!
# 📅 Months Registered with practice
# months_registered...DONE!
# 🗺️ Map Rota types
# map_rota_type...DONE!
# 🏷️ Labelencoding Sex
# labelencode_sex...DONE!
# 💧 Deseased and deducted
# filter_current_registration...DONE!
# 📅 Months Registered with practice
# calculate_days_difference...DONE!
# 🔥 OHE Ethnicity
# ohe_ethnicity...DONE!

# %%
data.head()
# Out:
#   Appointment booked date Appointment date Appointment status  \
# 0              2022-05-10       2022-07-14           Finished
# 1              2022-05-10       2022-07-14           Finished
# 2              2022-05-10       2022-07-14           Finished
# 3              2022-05-12       2022-07-05           Finished
# 4              2022-05-17       2022-07-05           Finished
#
#   Appointment time                  Booked by                  Clinician  \
# 0    10:00 - 10:59  FLORKO, Aleksandra (Miss)  FLORKO, Aleksandra (Miss)
# 1    10:00 - 10:59  FLORKO, Aleksandra (Miss)  FLORKO, Aleksandra (Miss)
# 2    10:00 - 10:59  FLORKO, Aleksandra (Miss)  FLORKO, Aleksandra (Miss)
# 3    09:00 - 09:59  FLORKO, Aleksandra (Miss)  FLORKO, Aleksandra (Miss)
# 4    10:00 - 10:59    LE TELLIER, Jean-Pierre  FLORKO, Aleksandra (Miss)
#
#   Rota type Patient ID         app datetime  temp  precipitation  \
# 0        GP   ae223de3  2022-07-14 10:00:00  21.6            0.0
# ...
